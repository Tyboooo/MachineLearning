# %% [markdown]
# # Exercise 06 Classification III

# %% [markdown]
# ## Pedagogy
#
# This notebook contains both theoretical explanations and executable cells to execute your code.
#
# When you see the <span style="color:red">**[TBC]**</span> (To Be Completed) sign, it means that you need to perform an action else besides executing the cells of code that already exist. These actions can be:
# - Complete the code with proper comments
# - Respond to a question
# - Write an analysis
# - etc.

# %% [markdown]
# ### Import libraries

# %%
# import all libraries used in this notebook here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.inspection import DecisionBoundaryDisplay

from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree

from sklearn.metrics import classification_report

# %% [markdown]
# ## Part 1. Decision Tree Classifier
#
# Build a binary classifier using decision tree algorithm for the [Breast cancer wisconsin (diagnostic) dataset](https://scikit-learn.org/stable/datasets/toy_dataset.html#breast-cancer-dataset)

# %% [markdown]
# ### Load dataset

# %%
# load dataset
feature_df, target_df = datasets.load_breast_cancer(
    return_X_y = True,
    as_frame = True
)

# %% [markdown]
# ### Train test split
#
# 70% as the training dataset and the rest as the testing dataset.
#
# Only keep the first two features as the inputs for the convenience of visualization
#
# Shuffle the entire dataset before spliting.
#
# Guarantee the reproducibility by fixing `random_state` as 0.

# %%
# train test split
X_train, X_test, y_train, y_test = train_test_split(
    feature_df[['mean radius', 'mean texture']].values,
    target_df.values,
    train_size = 0.7,
    shuffle = True,
    random_state = 0
)

# %% [markdown]
# ### Train the model
#
# Use `sklearn.tree.DecisionTreeClassifier` to implement a binary classifier.
#
# Use information gain as the criterion to select conditions for decision nodes by setting `criterion = 'entropy'`.
#
# First, let us grow a complete a tree without pruning.

# %%
# train a classifier using decision tree
clf = DecisionTreeClassifier(
    criterion = 'entropy', # use information gain as the criterion
)
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
# display the decision boundary learned from the training dataset
# plot decision boundary
disp = DecisionBoundaryDisplay.from_estimator(
    clf,
    X_train,
    response_method = "predict",
    plot_method = "pcolormesh",
    xlabel = 'mean radius',
    ylabel = 'mean texture',
    shading = "auto",
    alpha = 0.5
)
# plot training data points
disp.ax_.scatter(
    X_train[:, 0],
    X_train[:, 1],
    c = y_train,
    edgecolors = 'k'
)
plt.show()

# %% [markdown]
# From the displayed deicsion boundary we can find, the feature space is divided into many fragmented parts.
#
# In some parts, there is only one data points, which indicated we might get an over-fitted model.
#
# We can display the learned decision tree to check if there is an over-fitting.

# %%
# plot the tree structure
plt.figure(figsize = [40, 30])
plot_tree(clf)
plt.show()

# %% [markdown]
# From the displayed decision tree we can find, all leaf nodes are pure nodes.
#
# Most of the leaf nodes only contain one data point, which indicated there is an over-fitting.
#
# We need to pruning the tree to avoid that.
#
# `sklearn.tree.DecisionTreeClassifier` performs pre-pruning by setting different restriction hyper-parameters.
#
# For example, we can limit the maximum depth of the tree.

# %%
# pre-pruning by limiting the max depth of the tree
clf = DecisionTreeClassifier(
    criterion = 'entropy', # use information gain as the criterion
    max_depth = 2
)
clf.fit(X_train, y_train)
# plot the tree structure
plot_tree(clf)
plt.show()

# %%
# display the decision boundary learned from the training dataset
# plot decision boundary
disp = DecisionBoundaryDisplay.from_estimator(
    clf,
    X_train,
    response_method = "predict",
    plot_method = "pcolormesh",
    xlabel = 'mean radius',
    ylabel = 'mean texture',
    shading = "auto",
    alpha = 0.5
)
# plot training data points
disp.ax_.scatter(
    X_train[:, 0],
    X_train[:, 1],
    c = y_train,
    edgecolors = 'k'
)
plt.show()

# %% [markdown]
# ### Evaluate the model

# %%
# predict categories for testing dataset
y_pred = clf.predict(X_test)
# show the first 5 prediction
y_pred[:5]
# Out:
# array([1, 1, 1, 1, 1])

# %%
# predict probabilities for testing dataset
y_pred_proba = clf.predict_proba(X_test)
# show the first 5 predicted probability
y_pred_proba[:5, :]
# Out:
# array([[0.32258065, 0.67741935],
#        [0.32258065, 0.67741935],
#        [0.05759162, 0.94240838],
#        [0.05759162, 0.94240838],
#        [0.05759162, 0.94240838]])

# %%
# get all metrics using `classification_report`
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.73      0.83        63
#            1       0.86      0.98      0.92       108
#
#     accuracy                           0.89       171
#    macro avg       0.91      0.86      0.87       171
# weighted avg       0.90      0.89      0.88       171

# %% [markdown]
# ## Part 2. Hyper-parameter tuning through cross-validation
#
# In this part, we will perform hyper-parameter tuning for the decision tree classifier through 3-fold cross-validation to improve the model's performance.
#
# We will adopt the grid search strategy by using `sklearn.model_selection.GridSearchCV`.
#
# A search consists of:
#
# - a model (the decision tree classifier);
# - a hyper-parameter space (the values of hyper-parameters to search);
# - a method for searching or sampling candidates (grid search);
# - a cross-validation scheme (3-fold cross-validation); and
# - a score function (performance metric to compare different hyper-parameter combinations).

# %% [markdown]
# ### Define the hyper-parameter space

# %%
# define the hyper-parameters to search
param_dict = {
    'criterion': ['gini', 'entropy', 'log_loss'],
    'max_depth': [2, 3, 4]
}

# %% [markdown]
# ### Grid search
#
# `sklearn.model_selection.GridSearchCV` will trained a set of models with the same dataset (training and validation) but different hyper-parameters.
#
# We can specify `refit = True` to retrain a best model using the best hyper-parameters find by grid search and also the entire training dataset (no fold left for validation).
#
# We can get this best model by the attribute `GridSearchCV.best_estimator_`.

# %%
# hyper-parameter tuning through cross-validation
grid_clf = GridSearchCV(
    estimator = DecisionTreeClassifier(),
    param_grid = param_dict,
    scoring = 'f1_weighted',
    refit = True,
    cv = 3,
    verbose = 10
)
grid_clf.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV 1/3; 1/9] START criterion=gini, max_depth=2.................................
# [CV 1/3; 1/9] END ..criterion=gini, max_depth=2;, score=0.876 total time=   0.0s
# [CV 2/3; 1/9] START criterion=gini, max_depth=2.................................
# [CV 2/3; 1/9] END ..criterion=gini, max_depth=2;, score=0.861 total time=   0.0s
# [CV 3/3; 1/9] START criterion=gini, max_depth=2.................................
# [CV 3/3; 1/9] END ..criterion=gini, max_depth=2;, score=0.845 total time=   0.0s
# [CV 1/3; 2/9] START criterion=gini, max_depth=3.................................
# [CV 1/3; 2/9] END ..criterion=gini, max_depth=3;, score=0.916 total time=   0.0s
# [CV 2/3; 2/9] START criterion=gini, max_depth=3.................................
# [CV 2/3; 2/9] END ..criterion=gini, max_depth=3;, score=0.829 total time=   0.0s
# [CV 3/3; 2/9] START criterion=gini, max_depth=3.................................
# [CV 3/3; 2/9] END ..criterion=gini, max_depth=3;, score=0.873 total time=   0.0s
# [CV 1/3; 3/9] START criterion=gini, max_depth=4.................................
# [CV 1/3; 3/9] END ..criterion=gini, max_depth=4;, score=0.863 total time=   0.0s
# [CV 2/3; 3/9] START criterion=gini, max_depth=4.................................
# [CV 2/3; 3/9] END ..criterion=gini, max_depth=4;, score=0.844 total time=   0.0s
# [CV 3/3; 3/9] START criterion=gini, max_depth=4.................................
# [CV 3/3; 3/9] END ..criterion=gini, max_depth=4;, score=0.895 total time=   0.0s
# [CV 1/3; 4/9] START criterion=entropy, max_depth=2..............................
# [CV 1/3; 4/9] END criterion=entropy, max_depth=2;, score=0.876 total time=   0.0s
# [CV 2/3; 4/9] START criterion=entropy, max_depth=2..............................
# [CV 2/3; 4/9] END criterion=entropy, max_depth=2;, score=0.861 total time=   0.0s
# [CV 3/3; 4/9] START criterion=entropy, max_depth=2..............................
# [CV 3/3; 4/9] END criterion=entropy, max_depth=2;, score=0.860 total time=   0.0s
# [CV 1/3; 5/9] START criterion=entropy, max_depth=3..............................
# [CV 1/3; 5/9] END criterion=entropy, max_depth=3;, score=0.876 total time=   0.0s
# [CV 2/3; 5/9] START criterion=entropy, max_depth=3..............................
# [CV 2/3; 5/9] END criterion=entropy, max_depth=3;, score=0.829 total time=   0.0s
# [CV 3/3; 5/9] START criterion=entropy, max_depth=3..............................
# [CV 3/3; 5/9] END criterion=entropy, max_depth=3;, score=0.845 total time=   0.0s
# [CV 1/3; 6/9] START criterion=entropy, max_depth=4..............................
# [CV 1/3; 6/9] END criterion=entropy, max_depth=4;, score=0.875 total time=   0.0s
# [CV 2/3; 6/9] START criterion=entropy, max_depth=4..............................
# [CV 2/3; 6/9] END criterion=entropy, max_depth=4;, score=0.844 total time=   0.0s
# [CV 3/3; 6/9] START criterion=entropy, max_depth=4..............................
# [CV 3/3; 6/9] END criterion=entropy, max_depth=4;, score=0.880 total time=   0.0s
# [CV 1/3; 7/9] START criterion=log_loss, max_depth=2.............................
# [CV 1/3; 7/9] END criterion=log_loss, max_depth=2;, score=0.876 total time=   0.0s
# [CV 2/3; 7/9] START criterion=log_loss, max_depth=2.............................
# [CV 2/3; 7/9] END criterion=log_loss, max_depth=2;, score=0.861 total time=   0.0s
# [CV 3/3; 7/9] START criterion=log_loss, max_depth=2.............................
# [CV 3/3; 7/9] END criterion=log_loss, max_depth=2;, score=0.860 total time=   0.0s
# [CV 1/3; 8/9] START criterion=log_loss, max_depth=3.............................
# [CV 1/3; 8/9] END criterion=log_loss, max_depth=3;, score=0.876 total time=   0.0s
# [CV 2/3; 8/9] START criterion=log_loss, max_depth=3.............................
# [CV 2/3; 8/9] END criterion=log_loss, max_depth=3;, score=0.829 total time=   0.0s
# [CV 3/3; 8/9] START criterion=log_loss, max_depth=3.............................
# [CV 3/3; 8/9] END criterion=log_loss, max_depth=3;, score=0.845 total time=   0.0s
# [CV 1/3; 9/9] START criterion=log_loss, max_depth=4.............................
# [CV 1/3; 9/9] END criterion=log_loss, max_depth=4;, score=0.875 total time=   0.0s
# [CV 2/3; 9/9] START criterion=log_loss, max_depth=4.............................
# [CV 2/3; 9/9] END criterion=log_loss, max_depth=4;, score=0.844 total time=   0.0s
# [CV 3/3; 9/9] START criterion=log_loss, max_depth=4.............................
# [CV 3/3; 9/9] END criterion=log_loss, max_depth=4;, score=0.880 total time=   0.0s
# GridSearchCV(cv=3, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [2, 3, 4]},
#              scoring='f1_weighted', verbose=10)

# %%
# obtain the best hyper-parameters the best score
print('Best hyper-parameters:', grid_clf.best_params_)
print('Best score:', grid_clf.best_score_)
# Out:
# Best hyper-parameters: {'criterion': 'gini', 'max_depth': 3}
# Best score: 0.8727488059454654

# %%
# obtain the best estimator
plt.figure(figsize = [20, 8])
plot_tree(grid_clf.best_estimator_)
plt.show()

# %%
# display the decision boundary learned from the training dataset
# plot decision boundary
disp = DecisionBoundaryDisplay.from_estimator(
    grid_clf.best_estimator_,
    X_train,
    response_method = "predict",
    plot_method = "pcolormesh",
    xlabel = 'mean radius',
    ylabel = 'mean texture',
    shading = "auto",
    alpha = 0.5
)
# plot training data points
disp.ax_.scatter(
    X_train[:, 0],
    X_train[:, 1],
    c = y_train,
    edgecolors = 'k'
)
plt.show()

# %% [markdown]
# ### Final evaluation using the testing dataset

# %%
# predict categories for testing dataset
y_pred = grid_clf.predict(X_test)
# show the first 5 prediction
y_pred[:5]
# Out:
# array([0, 0, 1, 1, 1])

# %%
# predict probabilities for testing dataset
y_pred_proba = grid_clf.predict_proba(X_test)
# show the first 5 predicted probability
y_pred_proba[:5, :]
# Out:
# array([[0.60526316, 0.39473684],
#        [0.60526316, 0.39473684],
#        [0.09090909, 0.90909091],
#        [0.09090909, 0.90909091],
#        [0.09090909, 0.90909091]])

# %%
# get all metrics using `classification_report`
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.90      0.87        63
#            1       0.94      0.90      0.92       108
#
#     accuracy                           0.90       171
#    macro avg       0.89      0.90      0.89       171
# weighted avg       0.90      0.90      0.90       171

# %% [markdown]
# ## Part 3. Hands-on exercise
#
# In this exercise, we will build a multi-class classifier with the the [California Housing dataset](https://scikit-learn.org/stable/datasets/real_world.html#california-housing-dataset).
#
# The goal of the classifier is to perform a multi-class classification taks:
# - 0 represents 'Low Price', 'MedHouseVal' < 1
# - 1 represents 'Normal Price', 1 <= 'MedHouseVal' <= 2.5
# - 2 represents 'Expensive Price', 'MedHouseVal' > 2.5
#
# <span style="color:red">**[TBC]**</span> Please complete the following steps:
# - Build the classifier using decision tree.
# - Perform hyper-parameter tuning through cross-validation to improve model's performance.
#     - Use grid search strategy `sklearn.model_selection.GridSearchCV`
#     - Use random search strategy `sklearn.model_selection.RandomizedSearchCV`

# %% [markdown]
# ### Task 1. Load, pre-process, and split the dataset
#
# <span style="color:red">**[TBC]**</span> Please complete the following steps:
# - Load the dataset
# - Construct the new multi-class target variable use `MedHouseVal` as reference
# - Split the dataset into training and testing sets

# %%
# [TBC] complete your code here with proper comments
#load dataset
from sklearn.datasets import fetch_california_housing
feature_df, target_df  = fetch_california_housing(
    return_X_y = True, # return features and target separately
    as_frame = True, # return features and target as pandas DataFrame or Series
)

def update_values(x):
    if x < 1:
        return 0
    elif x > 2.5:
        return 2
    else: 
        return 1

# Apply the custom function to update values in the Series
target_df = target_df.apply(update_values)    
target_df

# train test split
X_train, X_test, y_train, y_test = train_test_split(
    feature_df.values,
    target_df.values,
    train_size = 0.7,
    shuffle = True,
    random_state = 0
)

# %% [markdown]
# ### Task 2. Hyper-parameter tuning using grid search strategy
#
# <span style="color:red">**[TBC]**</span> Please complete the following steps:
# - Define the hyper-parameters to search
#     - `criterion`
#     - `max_depth`
#     - `min_samples_split`
#     - `min_samples_leaf`
#     - `max_features`
#     - `min_impurity_decrease`
# - Perform grid search with cross-validation
#     - Check the best estimator and the best score
#     - If needed, refine the hyper-parameters to search, redo the grid search
#     - If good enough, continue with the best hyper-parameters found by the grid search
# - Train the model with the best hyper-parameters
# - Evaluate the performance with the testing dataset

# %%
# [TBC] complete your code here with proper comments
# define the hyper-parameters to search
param_dict = {
    'criterion': ['gini', 'entropy', 'log_loss'],
    'max_depth': [30,35,40],
    'min_samples_split': [10,15,20],
    'min_samples_leaf': [1,5,10],
    'max_features': [None, 'sqrt','log2'],
    'min_impurity_decrease': [0,0.1,0.2]  
}

# hyper-parameter tuning through cross-validation
grid_clf = GridSearchCV(
    estimator = DecisionTreeClassifier(),
    param_grid = param_dict,
    scoring = 'f1_weighted',
    refit = True,
    cv = 3,
    verbose = 10
)
grid_clf.fit(X_train, y_train)

# obtain the best hyper-parameters the best score
print('Best hyper-parameters:', grid_clf.best_params_)
print('Best score:', grid_clf.best_score_)

# obtain the best estimator
plt.figure(figsize = [20, 8])
plot_tree(grid_clf.best_estimator_)
plt.show()

# Train the model with the best hyper-parameters
grid_clf = grid_clf.best_estimator_
grid_clf.fit(X_train, y_train)

# Evaluate the performance with the testing dataset
test_score = grid_clf.score(X_test, y_test)
print('Test set score using best parameters:', test_score)
# Out:
# Fitting 3 folds for each of 729 candidates, totalling 2187 fits
# [CV 1/3; 1/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=10
# [CV 1/3; 1/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=10;, score=0.757 total time=   1.3s
# [CV 2/3; 1/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=10
# [CV 2/3; 1/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=10;, score=0.754 total time=   0.2s
# [CV 3/3; 1/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=10
# [CV 3/3; 1/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=10;, score=0.757 total time=   0.8s
# [CV 1/3; 2/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=15
# [CV 1/3; 2/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=15;, score=0.763 total time=   0.3s
# [CV 2/3; 2/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=15
# [CV 2/3; 2/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=15;, score=0.755 total time=   0.1s
# [CV 3/3; 2/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=15
# [CV 3/3; 2/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=15;, score=0.759 total time=   0.1s
# [CV 1/3; 3/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=20
# [CV 1/3; 3/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=20;, score=0.767 total time=   0.1s
# [CV 2/3; 3/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=20
# [CV 2/3; 3/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=20;, score=0.765 total time=   1.7s
# [CV 3/3; 3/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=20
# [CV 3/3; 3/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=20;, score=0.767 total time=   0.6s
# [CV 1/3; 4/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=5, min_samples_split=10
# [CV 1/3; 4/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=5, min_samples_split=10;, score=0.772 total time=   0.5s
# [CV 2/3; 4/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=5, min_samples_split=10
# [CV 2/3; 4/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=5, min_samples_split=10;, score=0.761 total time=   0.5s
# [CV 3/3; 4/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=5, min_samples_split=10
# [CV 3/3; 4/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=5, min_samples_split=10;, score=0.757 total time=   0.6s
# [CV 1/3; 5/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=5, min_samples_split=15
# [CV 1/3; 5/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=5, min_samples_split=15;, score=0.774 total time=   1.4s
# [CV 2/3; 5/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=5, min_samples_split=15
# [CV 2/3; 5/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=5, min_samples_split=15;, score=0.762 total time=   1.0s
# [CV 3/3; 5/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=5, min_samples_split=15
# [CV 3/3; 5/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=5, min_samples_split=15;, score=0.763 total time=   0.3s
# [CV 1/3; 6/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=5, min_samples_split=20
# [CV 1/3; 6/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=5, min_samples_split=20;, score=0.775 total time=   1.2s
# [CV 2/3; 6/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=5, min_samples_split=20
# [CV 2/3; 6/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=5, min_samples_split=20;, score=0.772 total time=   0.3s
# [CV 3/3; 6/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=5, min_samples_split=20
# [CV 3/3; 6/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=5, min_samples_split=20;, score=0.772 total time=   2.0s
# [CV 1/3; 7/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=10, min_samples_split=10
# [CV 1/3; 7/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=10, min_samples_split=10;, score=0.783 total time=   0.6s
# [CV 2/3; 7/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=10, min_samples_split=10
# [CV 2/3; 7/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=10, min_samples_split=10;, score=0.785 total time=   2.4s
# [CV 3/3; 7/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=10, min_samples_split=10
# [CV 3/3; 7/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=10, min_samples_split=10;, score=0.781 total time=   2.5s
# [CV 1/3; 8/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=10, min_samples_split=15
# [CV 1/3; 8/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=10, min_samples_split=15;, score=0.783 total time=   1.6s
# [CV 2/3; 8/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=10, min_samples_split=15
# [CV 2/3; 8/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=10, min_samples_split=15;, score=0.784 total time=   0.8s
# [CV 3/3; 8/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=10, min_samples_split=15
# [CV 3/3; 8/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=10, min_samples_split=15;, score=0.780 total time=   0.5s
# [CV 1/3; 9/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=10, min_samples_split=20
# [CV 1/3; 9/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=10, min_samples_split=20;, score=0.784 total time=   0.2s
# [CV 2/3; 9/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=10, min_samples_split=20
# [CV 2/3; 9/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=10, min_samples_split=20;, score=0.786 total time=   0.2s
# [CV 3/3; 9/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=10, min_samples_split=20
# [CV 3/3; 9/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0, min_samples_leaf=10, min_samples_split=20;, score=0.781 total time=   0.2s
# [CV 1/3; 10/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=10
# [CV 1/3; 10/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=10;, score=0.386 total time=   0.0s
# [CV 2/3; 10/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=10
# [CV 2/3; 10/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=10;, score=0.386 total time=   0.0s
# [CV 3/3; 10/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=10
# [CV 3/3; 10/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=10;, score=0.385 total time=   0.0s
# [CV 1/3; 11/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=15
# [CV 1/3; 11/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=15;, score=0.386 total time=   0.0s
# [CV 2/3; 11/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=15
# [CV 2/3; 11/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=15;, score=0.386 total time=   0.0s
# [CV 3/3; 11/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=15
# [CV 3/3; 11/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=15;, score=0.385 total time=   0.0s
# [CV 1/3; 12/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=20
# [CV 1/3; 12/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=20;, score=0.386 total time=   0.0s
# [CV 2/3; 12/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=20
# [CV 2/3; 12/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=20;, score=0.386 total time=   0.0s
# [CV 3/3; 12/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=20
# [CV 3/3; 12/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=20;, score=0.385 total time=   0.0s
# [CV 1/3; 13/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=10
# [CV 1/3; 13/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=10;, score=0.386 total time=   0.0s
# [CV 2/3; 13/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=10
# [CV 2/3; 13/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=10;, score=0.386 total time=   0.1s
# [CV 3/3; 13/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=10
# [CV 3/3; 13/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=10;, score=0.385 total time=   0.1s
# [CV 1/3; 14/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=15
# [CV 1/3; 14/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=15;, score=0.386 total time=   0.2s
# [CV 2/3; 14/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=15
# [CV 2/3; 14/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=15;, score=0.386 total time=   0.0s
# [CV 3/3; 14/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=15
# [CV 3/3; 14/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=15;, score=0.385 total time=   0.2s
# [CV 1/3; 15/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=20
# [CV 1/3; 15/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=20;, score=0.386 total time=   0.1s
# [CV 2/3; 15/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=20
# [CV 2/3; 15/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=20;, score=0.386 total time=   0.0s
# [CV 3/3; 15/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=20
# [CV 3/3; 15/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=20;, score=0.385 total time=   0.0s
# [CV 1/3; 16/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=10
# [CV 1/3; 16/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=10;, score=0.386 total time=   0.0s
# [CV 2/3; 16/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=10
# [CV 2/3; 16/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=10;, score=0.386 total time=   0.0s
# [CV 3/3; 16/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=10
# [CV 3/3; 16/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=10;, score=0.385 total time=   0.0s
# [CV 1/3; 17/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=15
# [CV 1/3; 17/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=15;, score=0.386 total time=   0.0s
# [CV 2/3; 17/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=15
# [CV 2/3; 17/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=15;, score=0.386 total time=   0.0s
# [CV 3/3; 17/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=15
# [CV 3/3; 17/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=15;, score=0.385 total time=   0.0s
# [CV 1/3; 18/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=20
# [CV 1/3; 18/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=20;, score=0.386 total time=   0.0s
# [CV 2/3; 18/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=20
# [CV 2/3; 18/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=20;, score=0.386 total time=   0.0s
# [CV 3/3; 18/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=20
# [CV 3/3; 18/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=20;, score=0.385 total time=   0.0s
# [CV 1/3; 19/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=10
# [CV 1/3; 19/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=10;, score=0.386 total time=   0.0s
# [CV 2/3; 19/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=10
# [CV 2/3; 19/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=10;, score=0.386 total time=   0.0s
# [CV 3/3; 19/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=10
# [CV 3/3; 19/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=10;, score=0.385 total time=   0.0s
# [CV 1/3; 20/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=15
# [CV 1/3; 20/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=15;, score=0.386 total time=   0.0s
# [CV 2/3; 20/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=15
# [CV 2/3; 20/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=15;, score=0.386 total time=   0.0s
# [CV 3/3; 20/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=15
# [CV 3/3; 20/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=15;, score=0.385 total time=   0.0s
# [CV 1/3; 21/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=20
# [CV 1/3; 21/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=20;, score=0.386 total time=   0.0s
# [CV 2/3; 21/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=20
# [CV 2/3; 21/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=20;, score=0.386 total time=   0.1s
# [CV 3/3; 21/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=20
# [CV 3/3; 21/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=20;, score=0.385 total time=   0.2s
# [CV 1/3; 22/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=10
# [CV 1/3; 22/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=10;, score=0.386 total time=   0.0s
# [CV 2/3; 22/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=10
# [CV 2/3; 22/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=10;, score=0.386 total time=   0.0s
# [CV 3/3; 22/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=10
# [CV 3/3; 22/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=10;, score=0.385 total time=   0.0s
# [CV 1/3; 23/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=15
# [CV 1/3; 23/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=15;, score=0.386 total time=   0.0s
# [CV 2/3; 23/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=15
# [CV 2/3; 23/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=15;, score=0.386 total time=   0.0s
# [CV 3/3; 23/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=15
# [CV 3/3; 23/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=15;, score=0.385 total time=   0.0s
# [CV 1/3; 24/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=20
# [CV 1/3; 24/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=20;, score=0.386 total time=   0.0s
# [CV 2/3; 24/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=20
# [CV 2/3; 24/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=20;, score=0.386 total time=   0.0s
# [CV 3/3; 24/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=20
# [CV 3/3; 24/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=20;, score=0.385 total time=   0.0s
# [CV 1/3; 25/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=10, min_samples_split=10
# [CV 1/3; 25/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=10, min_samples_split=10;, score=0.386 total time=   0.0s
# [CV 2/3; 25/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=10, min_samples_split=10
# [CV 2/3; 25/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=10, min_samples_split=10;, score=0.386 total time=   0.0s
# [CV 3/3; 25/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=10, min_samples_split=10
# [CV 3/3; 25/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=10, min_samples_split=10;, score=0.385 total time=   0.0s
# [CV 1/3; 26/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=10, min_samples_split=15
# [CV 1/3; 26/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=10, min_samples_split=15;, score=0.386 total time=   0.0s
# [CV 2/3; 26/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=10, min_samples_split=15
# [CV 2/3; 26/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=10, min_samples_split=15;, score=0.386 total time=   0.0s
# [CV 3/3; 26/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=10, min_samples_split=15
# [CV 3/3; 26/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=10, min_samples_split=15;, score=0.385 total time=   0.0s
# [CV 1/3; 27/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=10, min_samples_split=20
# [CV 1/3; 27/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=10, min_samples_split=20;, score=0.386 total time=   0.0s
# [CV 2/3; 27/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=10, min_samples_split=20
# [CV 2/3; 27/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=10, min_samples_split=20;, score=0.386 total time=   0.0s
# [CV 3/3; 27/729] START criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=10, min_samples_split=20
# [CV 3/3; 27/729] END criterion=gini, max_depth=30, max_features=None, min_impurity_decrease=0.2, min_samples_leaf=10, min_samples_split=20;, score=0.385 total time=   0.0s
# [CV 1/3; 28/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=10
# [CV 1/3; 28/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=10;, score=0.733 total time=   0.4s
# [CV 2/3; 28/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=10
# [CV 2/3; 28/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=10;, score=0.742 total time=   0.0s
# [CV 3/3; 28/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=10
# [CV 3/3; 28/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=10;, score=0.725 total time=   0.2s
# [CV 1/3; 29/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=15
# [CV 1/3; 29/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=15;, score=0.738 total time=   0.0s
# [CV 2/3; 29/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=15
# [CV 2/3; 29/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=15;, score=0.736 total time=   0.0s
# [CV 3/3; 29/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=15
# [CV 3/3; 29/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=15;, score=0.744 total time=   0.0s
# [CV 1/3; 30/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=20
# [CV 1/3; 30/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=20;, score=0.744 total time=   0.0s
# [CV 2/3; 30/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=20
# [CV 2/3; 30/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=20;, score=0.736 total time=   0.0s
# [CV 3/3; 30/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=20
# [CV 3/3; 30/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=20;, score=0.761 total time=   0.0s
# [CV 1/3; 31/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=5, min_samples_split=10
# [CV 1/3; 31/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=5, min_samples_split=10;, score=0.740 total time=   0.0s
# [CV 2/3; 31/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=5, min_samples_split=10
# [CV 2/3; 31/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=5, min_samples_split=10;, score=0.719 total time=   0.0s
# [CV 3/3; 31/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=5, min_samples_split=10
# [CV 3/3; 31/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=5, min_samples_split=10;, score=0.739 total time=   0.0s
# [CV 1/3; 32/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=5, min_samples_split=15
# [CV 1/3; 32/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=5, min_samples_split=15;, score=0.755 total time=   0.0s
# [CV 2/3; 32/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=5, min_samples_split=15
# [CV 2/3; 32/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=5, min_samples_split=15;, score=0.726 total time=   0.0s
# [CV 3/3; 32/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=5, min_samples_split=15
# [CV 3/3; 32/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=5, min_samples_split=15;, score=0.761 total time=   0.0s
# [CV 1/3; 33/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=5, min_samples_split=20
# [CV 1/3; 33/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=5, min_samples_split=20;, score=0.745 total time=   0.0s
# [CV 2/3; 33/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=5, min_samples_split=20
# [CV 2/3; 33/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=5, min_samples_split=20;, score=0.762 total time=   0.0s
# [CV 3/3; 33/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=5, min_samples_split=20
# [CV 3/3; 33/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=5, min_samples_split=20;, score=0.734 total time=   0.0s
# [CV 1/3; 34/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=10, min_samples_split=10
# [CV 1/3; 34/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=10, min_samples_split=10;, score=0.743 total time=   0.0s
# [CV 2/3; 34/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=10, min_samples_split=10
# [CV 2/3; 34/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=10, min_samples_split=10;, score=0.747 total time=   0.0s
# [CV 3/3; 34/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=10, min_samples_split=10
# [CV 3/3; 34/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=10, min_samples_split=10;, score=0.741 total time=   0.0s
# [CV 1/3; 35/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=10, min_samples_split=15
# [CV 1/3; 35/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=10, min_samples_split=15;, score=0.739 total time=   0.0s
# [CV 2/3; 35/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=10, min_samples_split=15
# [CV 2/3; 35/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=10, min_samples_split=15;, score=0.750 total time=   0.0s
# [CV 3/3; 35/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=10, min_samples_split=15
# [CV 3/3; 35/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=10, min_samples_split=15;, score=0.768 total time=   0.0s
# [CV 1/3; 36/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=10, min_samples_split=20
# [CV 1/3; 36/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=10, min_samples_split=20;, score=0.753 total time=   0.0s
# [CV 2/3; 36/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=10, min_samples_split=20
# [CV 2/3; 36/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=10, min_samples_split=20;, score=0.750 total time=   0.0s
# [CV 3/3; 36/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=10, min_samples_split=20
# [CV 3/3; 36/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=10, min_samples_split=20;, score=0.757 total time=   0.0s
# [CV 1/3; 37/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=10
# [CV 1/3; 37/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=10;, score=0.386 total time=   0.0s
# [CV 2/3; 37/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=10
# [CV 2/3; 37/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=10;, score=0.386 total time=   0.0s
# [CV 3/3; 37/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=10
# [CV 3/3; 37/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=10;, score=0.385 total time=   0.0s
# [CV 1/3; 38/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=15
# [CV 1/3; 38/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=15;, score=0.386 total time=   0.0s
# [CV 2/3; 38/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=15
# [CV 2/3; 38/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=15;, score=0.386 total time=   0.0s
# [CV 3/3; 38/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=15
# [CV 3/3; 38/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=15;, score=0.385 total time=   0.0s
# [CV 1/3; 39/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=20
# [CV 1/3; 39/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=20;, score=0.386 total time=   0.0s
# [CV 2/3; 39/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=20
# [CV 2/3; 39/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=20;, score=0.386 total time=   0.0s
# [CV 3/3; 39/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=20
# [CV 3/3; 39/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=20;, score=0.385 total time=   0.0s
# [CV 1/3; 40/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=10
# [CV 1/3; 40/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=10;, score=0.386 total time=   0.0s
# [CV 2/3; 40/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=10
# [CV 2/3; 40/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=10;, score=0.386 total time=   0.0s
# [CV 3/3; 40/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=10
# [CV 3/3; 40/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=10;, score=0.385 total time=   0.0s
# [CV 1/3; 41/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=15
# [CV 1/3; 41/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=15;, score=0.386 total time=   0.0s
# [CV 2/3; 41/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=15
# [CV 2/3; 41/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=15;, score=0.386 total time=   0.0s
# [CV 3/3; 41/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=15
# [CV 3/3; 41/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=15;, score=0.385 total time=   0.0s
# [CV 1/3; 42/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=20
# [CV 1/3; 42/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=20;, score=0.386 total time=   0.0s
# [CV 2/3; 42/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=20
# [CV 2/3; 42/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=20;, score=0.386 total time=   0.0s
# [CV 3/3; 42/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=20
# [CV 3/3; 42/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=20;, score=0.385 total time=   0.0s
# [CV 1/3; 43/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=10
# [CV 1/3; 43/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=10;, score=0.386 total time=   0.0s
# [CV 2/3; 43/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=10
# [CV 2/3; 43/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=10;, score=0.386 total time=   0.0s
# [CV 3/3; 43/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=10
# [CV 3/3; 43/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=10;, score=0.385 total time=   0.0s
# [CV 1/3; 44/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=15
# [CV 1/3; 44/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=15;, score=0.386 total time=   0.0s
# [CV 2/3; 44/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=15
# [CV 2/3; 44/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=15;, score=0.386 total time=   0.0s
# [CV 3/3; 44/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=15
# [CV 3/3; 44/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=15;, score=0.385 total time=   0.0s
# [CV 1/3; 45/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=20
# [CV 1/3; 45/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=20;, score=0.386 total time=   0.0s
# [CV 2/3; 45/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=20
# [CV 2/3; 45/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=20;, score=0.386 total time=   0.0s
# [CV 3/3; 45/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=20
# [CV 3/3; 45/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=20;, score=0.385 total time=   0.0s
# [CV 1/3; 46/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=10
# [CV 1/3; 46/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=10;, score=0.386 total time=   0.0s
# [CV 2/3; 46/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=10
# [CV 2/3; 46/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=10;, score=0.386 total time=   0.0s
# [CV 3/3; 46/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=10
# [CV 3/3; 46/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=10;, score=0.385 total time=   0.0s
# [CV 1/3; 47/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=15
# [CV 1/3; 47/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=15;, score=0.386 total time=   0.0s
# [CV 2/3; 47/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=15
# [CV 2/3; 47/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=15;, score=0.386 total time=   0.0s
# [CV 3/3; 47/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=15
# [CV 3/3; 47/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=15;, score=0.385 total time=   0.0s
# [CV 1/3; 48/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=20
# [CV 1/3; 48/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=20;, score=0.386 total time=   0.1s
# [CV 2/3; 48/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=20
# [CV 2/3; 48/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=20;, score=0.386 total time=   0.0s
# [CV 3/3; 48/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=20
# [CV 3/3; 48/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=20;, score=0.385 total time=   0.0s
# [CV 1/3; 49/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=10
# [CV 1/3; 49/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=10;, score=0.386 total time=   0.1s
# [CV 2/3; 49/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=10
# [CV 2/3; 49/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=10;, score=0.386 total time=   0.2s
# [CV 3/3; 49/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=10
# [CV 3/3; 49/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=10;, score=0.385 total time=   0.0s
# [CV 1/3; 50/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=15
# [CV 1/3; 50/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=15;, score=0.386 total time=   0.0s
# [CV 2/3; 50/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=15
# [CV 2/3; 50/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=15;, score=0.386 total time=   0.0s
# [CV 3/3; 50/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=15
# [CV 3/3; 50/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=15;, score=0.385 total time=   0.0s
# [CV 1/3; 51/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=20
# [CV 1/3; 51/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=20;, score=0.386 total time=   0.0s
# [CV 2/3; 51/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=20
# [CV 2/3; 51/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=20;, score=0.386 total time=   0.0s
# [CV 3/3; 51/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=20
# [CV 3/3; 51/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=20;, score=0.385 total time=   0.0s
# [CV 1/3; 52/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.2, min_samples_leaf=10, min_samples_split=10
# [CV 1/3; 52/729] END criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.2, min_samples_leaf=10, min_samples_split=10;, score=0.386 total time=   0.0s
# [CV 2/3; 52/729] START criterion=gini, max_depth=30, max_features=sqrt, min_impurity_decrease=0.2, min_samples_leaf=10, min_samples_split=10
# ...
# [CV 3/3; 713/729] END criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=15;, score=0.385 total time=   0.0s
# [CV 1/3; 714/729] START criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=20
# [CV 1/3; 714/729] END criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=20;, score=0.515 total time=   0.0s
# [CV 2/3; 714/729] START criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=20
# [CV 2/3; 714/729] END criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=20;, score=0.386 total time=   0.0s
# [CV 3/3; 714/729] START criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=20
# [CV 3/3; 714/729] END criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=20;, score=0.385 total time=   0.0s
# [CV 1/3; 715/729] START criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=10
# [CV 1/3; 715/729] END criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=10;, score=0.386 total time=   0.0s
# [CV 2/3; 715/729] START criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=10
# [CV 2/3; 715/729] END criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=10;, score=0.386 total time=   0.0s
# [CV 3/3; 715/729] START criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=10
# [CV 3/3; 715/729] END criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=10;, score=0.385 total time=   0.0s
# [CV 1/3; 716/729] START criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=15
# [CV 1/3; 716/729] END criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=15;, score=0.515 total time=   0.0s
# [CV 2/3; 716/729] START criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=15
# [CV 2/3; 716/729] END criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=15;, score=0.514 total time=   0.0s
# [CV 3/3; 716/729] START criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=15
# [CV 3/3; 716/729] END criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=15;, score=0.385 total time=   0.0s
# [CV 1/3; 717/729] START criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=20
# [CV 1/3; 717/729] END criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=20;, score=0.386 total time=   0.0s
# [CV 2/3; 717/729] START criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=20
# [CV 2/3; 717/729] END criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=20;, score=0.386 total time=   0.0s
# [CV 3/3; 717/729] START criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=20
# [CV 3/3; 717/729] END criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=20;, score=0.385 total time=   0.0s
# [CV 1/3; 718/729] START criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=10
# [CV 1/3; 718/729] END criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=10;, score=0.515 total time=   0.0s
# [CV 2/3; 718/729] START criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=10
# [CV 2/3; 718/729] END criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=10;, score=0.386 total time=   0.0s
# [CV 3/3; 718/729] START criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=10
# [CV 3/3; 718/729] END criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=10;, score=0.385 total time=   0.0s
# [CV 1/3; 719/729] START criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=15
# [CV 1/3; 719/729] END criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=15;, score=0.386 total time=   0.0s
# [CV 2/3; 719/729] START criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=15
# [CV 2/3; 719/729] END criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=15;, score=0.386 total time=   0.0s
# [CV 3/3; 719/729] START criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=15
# [CV 3/3; 719/729] END criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=15;, score=0.385 total time=   0.0s
# [CV 1/3; 720/729] START criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=20
# [CV 1/3; 720/729] END criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=20;, score=0.386 total time=   0.0s
# [CV 2/3; 720/729] START criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=20
# [CV 2/3; 720/729] END criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=20;, score=0.386 total time=   0.0s
# [CV 3/3; 720/729] START criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=20
# [CV 3/3; 720/729] END criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=20;, score=0.385 total time=   0.0s
# [CV 1/3; 721/729] START criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=10
# [CV 1/3; 721/729] END criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=10;, score=0.386 total time=   0.0s
# [CV 2/3; 721/729] START criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=10
# [CV 2/3; 721/729] END criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=10;, score=0.386 total time=   0.0s
# [CV 3/3; 721/729] START criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=10
# [CV 3/3; 721/729] END criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=10;, score=0.385 total time=   0.0s
# [CV 1/3; 722/729] START criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=15
# [CV 1/3; 722/729] END criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=15;, score=0.386 total time=   0.0s
# [CV 2/3; 722/729] START criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=15
# [CV 2/3; 722/729] END criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=15;, score=0.514 total time=   0.0s
# [CV 3/3; 722/729] START criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=15
# [CV 3/3; 722/729] END criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=15;, score=0.385 total time=   0.0s
# [CV 1/3; 723/729] START criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=20
# [CV 1/3; 723/729] END criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=20;, score=0.386 total time=   0.0s
# [CV 2/3; 723/729] START criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=20
# [CV 2/3; 723/729] END criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=20;, score=0.386 total time=   0.0s
# [CV 3/3; 723/729] START criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=20
# [CV 3/3; 723/729] END criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=1, min_samples_split=20;, score=0.385 total time=   0.0s
# [CV 1/3; 724/729] START criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=10
# [CV 1/3; 724/729] END criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=10;, score=0.386 total time=   0.0s
# [CV 2/3; 724/729] START criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=10
# [CV 2/3; 724/729] END criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=10;, score=0.386 total time=   0.0s
# [CV 3/3; 724/729] START criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=10
# [CV 3/3; 724/729] END criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=10;, score=0.385 total time=   0.0s
# [CV 1/3; 725/729] START criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=15
# [CV 1/3; 725/729] END criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=15;, score=0.515 total time=   0.0s
# [CV 2/3; 725/729] START criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=15
# [CV 2/3; 725/729] END criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=15;, score=0.386 total time=   0.0s
# [CV 3/3; 725/729] START criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=15
# [CV 3/3; 725/729] END criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=15;, score=0.385 total time=   0.0s
# [CV 1/3; 726/729] START criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=20
# [CV 1/3; 726/729] END criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=20;, score=0.386 total time=   0.0s
# [CV 2/3; 726/729] START criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=20
# [CV 2/3; 726/729] END criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=20;, score=0.386 total time=   0.0s
# [CV 3/3; 726/729] START criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=20
# [CV 3/3; 726/729] END criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=5, min_samples_split=20;, score=0.385 total time=   0.0s
# [CV 1/3; 727/729] START criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=10, min_samples_split=10
# [CV 1/3; 727/729] END criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=10, min_samples_split=10;, score=0.515 total time=   0.0s
# [CV 2/3; 727/729] START criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=10, min_samples_split=10
# [CV 2/3; 727/729] END criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=10, min_samples_split=10;, score=0.386 total time=   0.0s
# [CV 3/3; 727/729] START criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=10, min_samples_split=10
# [CV 3/3; 727/729] END criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=10, min_samples_split=10;, score=0.385 total time=   0.0s
# [CV 1/3; 728/729] START criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=10, min_samples_split=15
# [CV 1/3; 728/729] END criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=10, min_samples_split=15;, score=0.386 total time=   0.0s
# [CV 2/3; 728/729] START criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=10, min_samples_split=15
# [CV 2/3; 728/729] END criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=10, min_samples_split=15;, score=0.514 total time=   0.0s
# [CV 3/3; 728/729] START criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=10, min_samples_split=15
# [CV 3/3; 728/729] END criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=10, min_samples_split=15;, score=0.385 total time=   0.0s
# [CV 1/3; 729/729] START criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=10, min_samples_split=20
# [CV 1/3; 729/729] END criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=10, min_samples_split=20;, score=0.386 total time=   0.0s
# [CV 2/3; 729/729] START criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=10, min_samples_split=20
# [CV 2/3; 729/729] END criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=10, min_samples_split=20;, score=0.514 total time=   0.0s
# [CV 3/3; 729/729] START criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=10, min_samples_split=20
# [CV 3/3; 729/729] END criterion=log_loss, max_depth=40, max_features=log2, min_impurity_decrease=0.2, min_samples_leaf=10, min_samples_split=20;, score=0.385 total time=   0.0s
# Best hyper-parameters: {'criterion': 'gini', 'max_depth': 30, 'max_features': None, 'min_impurity_decrease': 0, 'min_samples_leaf': 10, 'min_samples_split': 20}
# Best score: 0.7834239163788758
# Test set score using best parameters: 0.7937994509930567

# %%
# Evaluate the performance with the testing dataset
test_score = grid_clf.score(X_test, y_test)
print('Test set score using best parameters:', test_score)

# Predict categories for the testing dataset
y_pred = grid_clf.predict(X_test)


# Get all metrics using `classification_report`
print(classification_report(y_test, y_pred))
# Out:
# Test set score using best parameters: 0.7937994509930567
#               precision    recall  f1-score   support
#
#            0       0.74      0.72      0.73      1074
#            1       0.80      0.83      0.82      3376
#            2       0.81      0.77      0.79      1743
#
#     accuracy                           0.79      6193
#    macro avg       0.78      0.77      0.78      6193
# weighted avg       0.79      0.79      0.79      6193

# %% [markdown]
# ### Task 3. Hyper-parameter tuning using random search strategy
#
# Instead of perform an exhausive grid search, using random search strategy instead.
#
# <span style="color:red">**[TBC]**</span> Please complete the following steps:
# - Define the hyper-parameters to search
# - Perform random search with cross-validation
# - Train the model with the best hyper-parameters
# - Evaluate the performance with the testing dataset

# %%
# [TBC] complete your code here with proper comments
from sklearn.model_selection import RandomizedSearchCV
# Randomized hyper-parameter search through cross-validation
random_clf = RandomizedSearchCV(
    estimator=DecisionTreeClassifier(),
    param_distributions=param_dict,
    n_iter=50,  # Number of random combinations to try
    scoring='f1_weighted',
    n_jobs=-1,  # Use all available cores
    cv=3,
    verbose=2,
    random_state=42
)
random_clf.fit(X_train, y_train)

# obtain the best hyper-parameters the best score
print('Best hyper-parameters:', random_clf.best_params_)
print('Best score:', random_clf.best_score_)

# obtain the best estimator
plt.figure(figsize = [20, 8])
plot_tree(random_clf.best_estimator_)
plt.show()


# Train the model with the best hyper-parameters
random_clf = random_clf.best_estimator_
random_clf.fit(X_train, y_train)

# Evaluate the performance with the testing dataset
test_score = random_clf.score(X_test, y_test)
print('Test set score using best parameters:', test_score)
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# Best hyper-parameters: {'min_samples_split': 15, 'min_samples_leaf': 10, 'min_impurity_decrease': 0, 'max_features': 'log2', 'max_depth': 40, 'criterion': 'log_loss'}
# Best score: 0.7785935122245616
# Test set score using best parameters: 0.7755530437590828

# %%
# predict categories for testing dataset
y_pred = random_clf.predict(X_test)

# Get all metrics using `classification_report`
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.71      0.72      1074
#            1       0.79      0.82      0.80      3376
#            2       0.78      0.73      0.76      1743
#
#     accuracy                           0.78      6193
#    macro avg       0.77      0.75      0.76      6193
# weighted avg       0.78      0.78      0.77      6193
